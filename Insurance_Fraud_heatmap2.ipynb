# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Insurance_df = pd.read_csv("Resources/Insurance_claims.csv")
Insurance_df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0      250/500               1000                1406.91               0
# 1      250/500               2000                1197.22         5000000
# 2      100/300               2000                1413.14         5000000
# 3      250/500               2000                1415.74         6000000
# 4     500/1000               1000                1583.91         6000000
# ..         ...                ...                    ...             ...
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0         466132  ...                     YES              71610         6510
# 1         468176  ...                       ?               5070          780
# 2         430632  ...                      NO              34650         7700
# 3         608117  ...                      NO              63400         6340
# 4         610706  ...                      NO               6500         1300
# ..           ...  ...                     ...                ...          ...
# 995       431289  ...                       ?              87200        17440
# 996       608177  ...                       ?             108480        18080
# 997       442797  ...                     YES              67500         7500
# 998       441714  ...                     YES              46980         5220
# 999       612260  ...                       ?               5060          460
#
#     property_claim vehicle_claim   auto_make  auto_model auto_year  \
# 0            13020         52080        Saab         92x      2004
# 1              780          3510    Mercedes        E400      2007
# 2             3850         23100       Dodge         RAM      2007
# 3             6340         50720   Chevrolet       Tahoe      2014
# 4              650          4550      Accura         RSX      2009
# ..             ...           ...         ...         ...       ...
# 995           8720         61040       Honda      Accord      2006
# 996          18080         72320  Volkswagen      Passat      2015
# 997           7500         52500      Suburu     Impreza      1996
# 998           5220         36540        Audi          A5      1998
# 999            920          3680    Mercedes        E400      2007
#
#     fraud_reported _c39
# 0                Y  NaN
# 1                Y  NaN
# 2                N  NaN
# 3                Y  NaN
# 4                N  NaN
# ..             ...  ...
# 995              N  NaN
# 996              N  NaN
# 997              N  NaN
# 998              N  NaN
# 999              N  NaN
#
# [1000 rows x 40 columns]

# %%
# Determine the number of unique values in each column.
Insurance_df.nunique()
# Out:
# months_as_customer              391
# age                              46
# policy_number                  1000
# policy_bind_date                951
# policy_state                      3
# policy_csl                        3
# policy_deductable                 3
# policy_annual_premium           991
# umbrella_limit                   11
# insured_zip                     995
# insured_sex                       2
# insured_education_level           7
# insured_occupation               14
# insured_hobbies                  20
# insured_relationship              6
# capital-gains                   338
# capital-loss                    354
# incident_date                    60
# incident_type                     4
# collision_type                    4
# incident_severity                 4
# authorities_contacted             5
# incident_state                    7
# incident_city                     7
# incident_location              1000
# incident_hour_of_the_day         24
# number_of_vehicles_involved       4
# property_damage                   3
# bodily_injuries                   3
# witnesses                         4
# police_report_available           3
# total_claim_amount              763
# injury_claim                    638
# property_claim                  626
# vehicle_claim                   726
# auto_make                        14
# auto_model                       39
# auto_year                        21
# fraud_reported                    2
# _c39                              0
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
insurance_type_counts= Insurance_df['fraud_reported'].value_counts()
insurance_type_counts
# Out:
# N    753
# Y    247
# Name: fraud_reported, dtype: int64

# %%
# Visualize the value counts of APPLICATION_TYPE
insurance_type_counts.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df=Insurance_df.loc[:,['policy_state','policy_deductable','policy_annual_premium','umbrella_limit',
                       'capital-gains','capital-loss','collision_type','incident_state','incident_city',
                      'property_damage','bodily_injuries','total_claim_amount','injury_claim', 'property_claim', 
                       'vehicle_claim', 'auto_make','auto_model','fraud_reported']]
df
# Out:
#     policy_state  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0             OH               1000                1406.91               0
# 1             IN               2000                1197.22         5000000
# 2             OH               2000                1413.14         5000000
# 3             IL               2000                1415.74         6000000
# 4             IL               1000                1583.91         6000000
# ..           ...                ...                    ...             ...
# 995           OH               1000                1310.80               0
# 996           IL               1000                1436.79               0
# 997           OH                500                1383.49         3000000
# 998           IL               2000                1356.92         5000000
# 999           OH               1000                 766.19               0
#
#      capital-gains  capital-loss   collision_type incident_state  \
# 0            53300             0   Side Collision             SC
# 1                0             0                ?             VA
# 2            35100             0   Rear Collision             NY
# 3            48900        -62400  Front Collision             OH
# 4            66000        -46000                ?             NY
# ..             ...           ...              ...            ...
# 995              0             0  Front Collision             NC
# 996          70900             0   Rear Collision             SC
# 997          35100             0   Side Collision             NC
# 998              0             0   Rear Collision             NY
# 999              0             0                ?             WV
#
#     incident_city property_damage  bodily_injuries  total_claim_amount  \
# 0        Columbus             YES                1               71610
# 1       Riverwood               ?                0                5070
# 2        Columbus              NO                2               34650
# 3       Arlington               ?                1               63400
# 4       Arlington              NO                0                6500
# ..            ...             ...              ...                 ...
# 995    Northbrook             YES                0               87200
# 996     Northbend             YES                2              108480
# 997     Arlington               ?                2               67500
# 998     Arlington               ?                0               46980
# 999      Columbus               ?                0                5060
#
#      injury_claim  property_claim  vehicle_claim   auto_make auto_model  \
# 0            6510           13020          52080        Saab        92x
# 1             780             780           3510    Mercedes       E400
# 2            7700            3850          23100       Dodge        RAM
# 3            6340            6340          50720   Chevrolet      Tahoe
# 4            1300             650           4550      Accura        RSX
# ..            ...             ...            ...         ...        ...
# 995         17440            8720          61040       Honda     Accord
# 996         18080           18080          72320  Volkswagen     Passat
# 997          7500            7500          52500      Suburu    Impreza
# 998          5220            5220          36540        Audi         A5
# 999           460             920           3680    Mercedes       E400
#
#     fraud_reported
# 0                Y
# 1                Y
# 2                N
# 3                Y
# 4                N
# ..             ...
# 995              N
# 996              N
# 997              N
# 998              N
# 999              N
#
# [1000 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['policy_state', 'policy_deductable', 'policy_annual_premium',
#        'umbrella_limit', 'capital-gains', 'capital-loss', 'collision_type',
#        'incident_state', 'incident_city', 'property_damage', 'bodily_injuries',
#        'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim',
#        'auto_make', 'auto_model', 'fraud_reported'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   policy_state           1000 non-null   object
#  1   policy_deductable      1000 non-null   int64
#  2   policy_annual_premium  1000 non-null   float64
#  3   umbrella_limit         1000 non-null   int64
#  4   capital-gains          1000 non-null   int64
#  5   capital-loss           1000 non-null   int64
#  6   collision_type         1000 non-null   object
#  7   incident_state         1000 non-null   object
#  8   incident_city          1000 non-null   object
#  9   property_damage        1000 non-null   object
#  10  bodily_injuries        1000 non-null   int64
#  11  total_claim_amount     1000 non-null   int64
#  12  injury_claim           1000 non-null   int64
#  13  property_claim         1000 non-null   int64
#  14  vehicle_claim          1000 non-null   int64
#  15  auto_make              1000 non-null   object
#  16  auto_model             1000 non-null   object
#  17  fraud_reported         1000 non-null   object
# dtypes: float64(1), int64(9), object(8)
# memory usage: 140.8+ KB

# %%
df=Insurance_df.loc[:,['policy_number','capital-gains','capital-loss','bodily_injuries','total_claim_amount','injury_claim', 'property_claim', 
                       'vehicle_claim','fraud_reported']]
df.head(20)
# Out:
#     policy_number  capital-gains  capital-loss  bodily_injuries  \
# 0          521585          53300             0                1
# 1          342868              0             0                0
# 2          687698          35100             0                2
# 3          227811          48900        -62400                1
# 4          367455          66000        -46000                0
# 5          104594              0             0                0
# 6          413978              0        -77000                0
# 7          429027              0             0                2
# 8          485665              0             0                1
# 9          636550              0        -39300                2
# 10         543610          38400             0                2
# 11         214618              0        -51000                1
# 12         842643              0             0                1
# 13         626808          52800        -32800                1
# 14         644081          41300        -55500                0
# 15         892874          55700             0                0
# 16         558938          63600             0                1
# 17         275265          53500             0                0
# 18         921202          45500        -37800                1
# 19         143972          57000        -27300                2
#
#     total_claim_amount  injury_claim  property_claim  vehicle_claim  \
# 0                71610          6510           13020          52080
# 1                 5070           780             780           3510
# 2                34650          7700            3850          23100
# 3                63400          6340            6340          50720
# 4                 6500          1300             650           4550
# 5                64100          6410            6410          51280
# 6                78650         21450            7150          50050
# 7                51590          9380            9380          32830
# 8                27700          2770            2770          22160
# 9                42300          4700            4700          32900
# 10               87010          7910           15820          63280
# 11              114920         17680           17680          79560
# 12               56520          4710            9420          42390
# 13                7280          1120            1120           5040
# 14               46200          4200            8400          33600
# 15               63120         10520           10520          42080
# 16               52110          5790            5790          40530
# 17               77880         14160            7080          56640
# 18               72930          6630           13260          53040
# 19               60400          6040            6040          48320
#
#    fraud_reported
# 0               Y
# 1               Y
# 2               N
# 3               Y
# 4               N
# 5               Y
# 6               N
# 7               N
# 8               N
# 9               N
# 10              N
# 11              N
# 12              N
# 13              N
# 14              Y
# 15              Y
# 16              N
# 17              N
# 18              N
# 19              N

# %%
#heatmap 
plt.figure(figsize = (13,5))
corr = df.corr()
sns.heatmap(corr, cbar=0, linewidths=2,vmax=1, vmin=0, square=True, cmap='Greens', annot =  True,  linewidth =1,fmt = '.2g',data = corr)
plt.show()
